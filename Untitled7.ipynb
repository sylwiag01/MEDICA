# %% [markdown]
# <a href="https://colab.research.google.com/github/sylwiag01/MEDICA/blob/main/Untitled7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
class Drzewo_Binarne:
    def __init__(self, key):
        self.key = key
        self.left = None
        self.right = None

    def insert_left(self, key):
        t = Drzewo_Binarne(key)
        if self.left is None:
            self.left = t
        else:
            t.left = self.left
            self.left = t

    def insert_right(self, key):
        t = Drzewo_Binarne(key)
        if self.right is None:
            self.right = t
        else:
            t.right = self.right
            self.right = t

    def get_left_child(self):
        return self.left

    def get_right_child(self):
        return self.right

    def set_root_val(self, obj):
        self.key = obj

    def get_root_val(self):
        return self.key

    def __str__(self):
        return f"[{self.key}; {self.left}; {self.right}]"

def print_menu():
    print("\nMenu:")
    print("1. Utwórz drzewo binarne")
    print("2. Dodaj dziecko")
    print("3. Wyświetl drzewo")
    print("4. Przeszukaj drzewo")
    print("5. Ustaw wartość węzła")
    print("6. Pobierz wartość węzła")
    print("7. Zakończ")

def main():
    tree = None

    while True:
        print_menu()
        choice = input("Wybierz opcję: ")

        if choice == "1":
            key = input("Podaj wartość dla korzenia drzewa: ")
            tree = Drzewo_Binarne(key)
            print(f"Utworzono drzewo z korzeniem: {tree.key}")

        elif choice == "2":
            if tree:
                key = input("Podaj wartość dla dziecka: ")
                  if (key < )
                    tree.insert_left(key)
                    print(f"Dodano lewe dziecko o wartości: {key}")

                  elif:
                    tree.insert_right(key >= )
                    print(f"Dodano prawe dziecko o wartości: {key}")

            else:
                print("Drzewo nie istnieje. Najpierw utwórz drzewo.")

        elif choice == "3":
            if tree:
                print("Drzewo binarne:")
                print(tree)
            else:
                print("Drzewo nie istnieje.")

        elif choice == "4":
            if tree:
                pass
            else:
                print("Drzewo nie istnieje.")

        elif choice == "5":
            if tree:
                key = input("Podaj nową wartość dla korzenia: ")
                tree.set_root_val(key)
                print(f"Zmieniono wartość korzenia na: {key}")
            else:
                print("Drzewo nie istnieje.")

        elif choice == "6":
            if tree:
                print(f"Wartość korzenia: {tree.get_root_val()}")
            else:
                print("Drzewo nie istnieje.")

        elif choice == "7":
            print("Zakończono działanie programu.")
            break

        else:
            print("Nieprawidłowy wybór. Spróbuj ponownie.")

if __name__ == "__main__":
    main()
# Out:
#   File "<ipython-input-5-b251d100ef17>", line 63
#     if (key < Drzewo_Binarne(key))
#     ^
# IndentationError: unexpected indent
